# %% [markdown]
# # Python Testing Script
# Use this template to create a Python testing script that imports your CRUD Python module to call and test the create and read instances of CRUD functionality.
# ### 1. Import your CRUD Python module
# ### 2. Instantiate an instance of your class
# ### 3. Use your create function create a new record in the aac database
# ### 4. Use your read funtion to return records from the aac database
# ### 5. Use your update function to update an existing record in the aac database
# ### 6. Use your delete function to delete an existing record in the aac database
#
# <div class="alert alert-block alert-success"><span style="color:black;"><b>Tip: </b>You should have created test functionality for items 1 thru 4 during Module Four Milestone, copy over your existing test script code and expand it here to call and test the Update and Delete functionality.</span></div>

# %%
from CRUD_Python_Module import AnimalShelter

#initialize database
test = AnimalShelter('aacuser', 'SNHU1234', 'aac', 'animals')

#valid create
print(test.create({ 
 'age_upon_outcome': "1 years",
 'animal_id': "1998",
 'animal_type': "Cat",
 'breed': "Domestic Shorthair",
 'color': "Dil. Tortoiseshell",
 'date_of_birth': "2022-03-27",
 'datetime': "2022-03-27 11:14:00",
 'monthyear': "2022-03-27T11:14:00",
 'name': "Venus",
 'outcome_subtype': "",
 'outcome_type': 'Adoption',
 'sex_upon_outcome': "Spayed Female",
 'location_lat': 30.6525984560228,
 'location_long': -97.7419963476444,
 'age_upon_outcome_in_weeks': 52.9215277777778}))
# Out:
# True

# %%
#valid read
test.read({"name": "Venus"})
# Out:
# {'_id': ObjectId('6a0f922b42740b08cd3a391f'), 'rec_num': 4094, 'age_upon_outcome': '7 years', 'animal_id': 'A749928', 'animal_type': 'Dog', 'breed': 'German Shepherd Mix', 'color': 'Sable/White', 'date_of_birth': '2010-05-21', 'datetime': '2017-08-08 07:52:00', 'monthyear': '2017-08-08T07:52:00', 'name': 'Venus', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.3220464876029, 'location_long': -97.5258416513768, 'age_upon_outcome_in_weeks': 376.618253968254}
# {'_id': ObjectId('6a2214d387f2a053f5bdb29a'), 'age_upon_outcome': '1 years', 'animal_id': '1998', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair', 'color': 'Dil. Tortoiseshell', 'date_of_birth': '2022-03-27', 'datetime': '2022-03-27 11:14:00', 'monthyear': '2022-03-27T11:14:00', 'name': 'Venus', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.6525984560228, 'location_long': -97.7419963476444, 'age_upon_outcome_in_weeks': 52.9215277777778}
# [{'_id': ObjectId('6a0f922b42740b08cd3a391f'),
#   'rec_num': 4094,
#   'age_upon_outcome': '7 years',
#   'animal_id': 'A749928',
#   'animal_type': 'Dog',
#   'breed': 'German Shepherd Mix',
#   'color': 'Sable/White',
#   'date_of_birth': '2010-05-21',
#   'datetime': '2017-08-08 07:52:00',
#   'monthyear': '2017-08-08T07:52:00',
#   'name': 'Venus',
#   'outcome_subtype': 'Foster',
#   'outcome_type': 'Adoption',
#   'sex_upon_outcome': 'Spayed Female',
#   'location_lat': 30.3220464876029,
#   'location_long': -97.5258416513768,
#   'age_upon_outcome_in_weeks': 376.618253968254},
#  {'_id': ObjectId('6a2214d387f2a053f5bdb29a'),
#   'age_upon_outcome': '1 years',
#   'animal_id': '1998',
#   'animal_type': 'Cat',
#   'breed': 'Domestic Shorthair',
#   'color': 'Dil. Tortoiseshell',
#   'date_of_birth': '2022-03-27',
#   'datetime': '2022-03-27 11:14:00',
#   'monthyear': '2022-03-27T11:14:00',
#   'name': 'Venus',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'sex_upon_outcome': 'Spayed Female',
#   'location_lat': 30.6525984560228,
#   'location_long': -97.7419963476444,
#   'age_upon_outcome_in_weeks': 52.9215277777778}]

# %%
#valid update
test.update({"animal_id": "1998"}, {"$set": {"name": "Benus"}})
test.read({"name": "Benus"})

#valid delete
test.delete({"name": "Benus"})
# Out:
# modified 1 result
# {'_id': ObjectId('6a2214d387f2a053f5bdb29a'), 'age_upon_outcome': '1 years', 'animal_id': '1998', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair', 'color': 'Dil. Tortoiseshell', 'date_of_birth': '2022-03-27', 'datetime': '2022-03-27 11:14:00', 'monthyear': '2022-03-27T11:14:00', 'name': 'Benus', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.6525984560228, 'location_long': -97.7419963476444, 'age_upon_outcome_in_weeks': 52.9215277777778}
# deleted 1 result
